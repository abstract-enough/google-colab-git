# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# create personal access token (classic)
#
# git profile:
#
# settings
#
# developer settings
#
# create personal access token (classic)
#
# (give repo permissions)

# %%
token="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"

# %%
repo_names = [ \
"to-do",
"resume",
"source_generator",
"inverse-square-signal-separation",
"google-colab-git",
"glimpses-of-cradock",
"display-large-prime",
"fourier_random_smooth",
"electrophoresis-vision",
"godel-escher-block",
"SSVEP-stimulus",
"format-thumb"]

# %%
folder_name ="/content/drive/MyDrive/a2_current/backup_github/"

# %%
#for repo_name in repo_names:
#  clone_arg_1 = "https://abstract-enough:"+token+"@github.com/abstract-enough/"+repo_name
#  clone_arg_2 = folder_name+repo_name
#  !git clone $clone_arg_1 $clone_arg_2

# %%
for repo_name in repo_names:

  pull_str = "git pull https://abstract-enough:"+token+"@github.com//abstract-enough/"+repo_name+".git"
  folder_str = folder_name+repo_name
  # !bash -c "cd $folder_str; $pull_str"
# Out:
# From https://github.com//abstract-enough/to-do
#  * branch            HEAD       -> FETCH_HEAD
# Already up to date.
# From https://github.com//abstract-enough/resume
#  * branch            HEAD       -> FETCH_HEAD
# Already up to date.
# From https://github.com//abstract-enough/source_generator
#  * branch            HEAD       -> FETCH_HEAD
# Already up to date.
# From https://github.com//abstract-enough/inverse-square-signal-separation
#  * branch            HEAD       -> FETCH_HEAD
# Already up to date.
# From https://github.com//abstract-enough/google-colab-git
#  * branch            HEAD       -> FETCH_HEAD
# Already up to date.
# From https://github.com//abstract-enough/glimpses-of-cradock
#  * branch            HEAD       -> FETCH_HEAD
# Already up to date.
# From https://github.com//abstract-enough/display-large-prime
#  * branch            HEAD       -> FETCH_HEAD
# Already up to date.
# From https://github.com//abstract-enough/fourier_random_smooth
# ...
