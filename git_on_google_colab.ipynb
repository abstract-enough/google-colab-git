# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# create fine grained personal access token
# git profile:
# settings
# developer settings
# create fine grained personal access token

# %%
# !bash -c token="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"

# %%
#!git clone 'https://abstract-enough:${token}@github.com/abstract-enough/abstract-enough.github.io' /content/drive/MyDrive/a1_files/website_backup/abstract-enough
# Out:
# Cloning into '/content/drive/MyDrive/a1_files/website_backup/abstract-enough'...
# remote: Enumerating objects: 2318, done.
# remote: Counting objects: 100% (588/588), done.
# remote: Compressing objects: 100% (207/207), done.
# remote: Total 2318 (delta 532), reused 381 (delta 381), pack-reused 1730 (from 3)
# Receiving objects: 100% (2318/2318), 92.84 MiB | 12.38 MiB/s, done.
# Resolving deltas: 100% (1406/1406), done.
# Updating files: 100% (73/73), done.

# %%
# !bash -c 'cd /content/drive/MyDrive/a1_files/website_backup/abstract-enough; git pull https://abstract-enough:${token}@github.com/abstract-enough/abstract-enough.github.io'
# Out:
# ...
# From https://github.com/abstract-enough/abstract-enough.github.io
#  * branch            HEAD       -> FETCH_HEAD
# Already up to date.
