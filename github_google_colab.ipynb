# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# create personal access token (classic)
#
# git profile:
#
# settings
#
# developer settings
#
# create personal access token (classic)
#
# (give repo permissions)

# %%
token="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"

# %%
repo_name = "to-do"
user_name = "abstract-enough"
google_drive_folder = "/content/drive/MyDrive/a2_current/backup_github/"

# %% [markdown]
# Only run the next cell one time

# %%
#clone_arg_1 = "https://"+user_name+":"+token+"@github.com/"+user_name+"/"+repo_name+".git"
#clone_arg_2 = google_drive_folder+repo_name
#!git clone $clone_arg_1 $clone_arg_2

# %%
pull_str = "git pull https://"+user_name+":"+token+"@github.com//"+user_name+"/"+repo_name+".git"
folder_name = google_drive_folder+repo_name
# !bash -c "cd $folder_name; $pull_str"
# Out:
# From https://github.com//abstract-enough/to-do
#  * branch            HEAD       -> FETCH_HEAD
# Already up to date.
